# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv('Superstore.csv')
df = pd.read_csv('Superstore.csv', encoding='latin1')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %% [markdown]
# # Rename Columns

# %%
# df = pd.rename(" ","",columns = {df.columns}
df.columns = df.columns.str.replace(" ","_",regex = True).str.replace("-","_",regex = True)

# %%
# df = pd.rename(" ","",columns = {df.columns}
# df.columns = df.columns.str.replace(df.columns,lower(df.columns),regex = True).str.replace("-","_",regex = True)
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='str')

# %%
# Check for NULL

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int64
#  1   order_id       9994 non-null   str
#  2   order_date     9994 non-null   str
#  3   ship_date      9994 non-null   str
#  4   ship_mode      9994 non-null   str
#  5   customer_id    9994 non-null   str
#  6   customer_name  9994 non-null   str
#  7   segment        9994 non-null   str
#  8   country        9994 non-null   str
#  9   city           9994 non-null   str
#  10  state          9994 non-null   str
#  11  postal_code    9994 non-null   int64
#  12  region         9994 non-null   str
#  13  product_id     9994 non-null   str
#  14  category       9994 non-null   str
#  15  sub_category   9994 non-null   str
#  16  product_name   9994 non-null   str
#  17  sales          9994 non-null   float64
#  18  quantity       9994 non-null   int64
# ...

# %%
df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub_category  \
# ...

# %% [markdown]
# # Export Cleaned DataSet

# %%
df.to_csv('cleaned_data.csv')

# %%
df_sales_data = pd.read_csv('sales_data.csv')

# %%
len(df.columns)
# Out:
# 21

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='str')

# %%
len(df_sales_data.columns)
# Out:
# 21

# %%
import datetime as dt

# %%
df['order_date']
# Out:
# 0        11/8/2016
# 1        11/8/2016
# 2        6/12/2016
# 3       10/11/2015
# 4       10/11/2015
#            ...
# 9989     1/21/2014
# 9990     2/26/2017
# 9991     2/26/2017
# 9992     2/26/2017
# 9993      5/4/2017
# Name: order_date, Length: 9994, dtype: str

# %%
# df['order_date'] = datetime("%D-%M-%Y",'order_date')

# %%
max_length = (
    df.astype(str)
      .apply(lambda col: col.str.len().max())
      .reset_index()
)

max_length.columns = ['Column_Name', 'Max_Length']

print(max_length)
# Out:
#       Column_Name  Max_Length
# 0          row_id           4
# 1        order_id          14
# 2      order_date          10
# 3       ship_date          10
# 4       ship_mode          14
# 5     customer_id           8
# 6   customer_name          22
# 7         segment          11
# 8         country          13
# 9            city          17
# 10          state          20
# 11    postal_code           5
# 12         region           7
# 13     product_id          15
# 14       category          15
# 15   sub_category          11
# 16   product_name         127
# 17          sales           9
# 18       quantity           2
# 19       discount           4
# 20         profit          10

# %% [markdown]
# # Change Data types of columns

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='str')

# %%
df['row_id'] = df['row_id'].astype(int)

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
col = df.columns[4:17]
df[col] = df[col].astype(str)

# %%
df[col].dtypes
# Out:
# ship_mode        str
# customer_id      str
# customer_name    str
# segment          str
# country          str
# city             str
# state            str
# postal_code      str
# region           str
# product_id       str
# category         str
# sub_category     str
# product_name     str
# dtype: object

# %%
df['order_id'] = df['order_id'].astype(str)

# %%
df['quantity'] = df['quantity'].astype(int)
df['discount'] = df['discount'].astype(float)
df['profit'] = df['profit'].astype(float)

# %%
df.dtypes
# Out:
# row_id                    int64
# order_id                    str
# order_date       datetime64[us]
# ship_date        datetime64[us]
# ship_mode                   str
# customer_id                 str
# customer_name               str
# segment                     str
# country                     str
# city                        str
# state                       str
# postal_code                 str
# region                      str
# product_id                  str
# category                    str
# sub_category                str
# product_name                str
# sales                   float64
# quantity                  int64
# discount                float64
# profit                  float64
# dtype: object

# %%
df.to_csv('cleaned_sale.csv')
